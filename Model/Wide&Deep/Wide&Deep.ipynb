# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Layer, Dropout
from tensorflow.keras.regularizers import l2

# %%
class Linear(Layer):
    def __init__(self,feature_length,w_reg=1e-6):
        """
        Linear Part
        :param feature_length: A scalar. The length of features.
        :param w_reg: A scalar. The regularization coefficient of parameter w.
        """
        super(Linear,self).__init__()
        self.feature_length = feature_length
        self.w_reg =w_reg
    def build(self,input_shape):      
        self.w = self.add_weight(name="w",
                                 shape=(self.feature_length, 1),
                                 regularizer=l2(self.w_reg),
                                 trainable=True)


#     def build(self, input_shape):
#         self.w = self.add_weight(name="w",
#                                  shape=(self.feature_length, 1),
#                                  regularizer=l2(self.w_reg),
#                                  trainable=True) 
    
    def call(self,inputs,**kwargs):
        result = tf.reduce_sum(tf.nn.embedding_lookup(self.w, inputs), axis=1)  # (batch_size, 1)
        return result
    
class DNN(Layer):
    def __init__(self, hidden_units, activation='relu', dropout=0.):
        """Deep Neural Network
        :param hidden_units: A list. Neural network hidden units.
        :param activation: A string. Activation function of dnn.
        :param dropout: A scalar. Dropout number.
        """
        super(DNN, self).__init__()
        self.dnn_network = [Dense(units=unit, activation=activation) for unit in hidden_units]
        self.dropout = Dropout(dropout)
        
    def call(self,inputs,**kwargs):
        x = inputs
        for dnn in self.dnn_network:
            x = dnn(x)
        x = self.dropout(x)
        return x


# class Linear(Layer):
#     def __init__(self, feature_length, w_reg=1e-6):
#         """
#         Linear Part
#         :param feature_length: A scalar. The length of features.
#         :param w_reg: A scalar. The regularization coefficient of parameter w.
#         """
#         super(Linear, self).__init__()
#         self.feature_length = feature_length
#         self.w_reg = w_reg

#     def build(self, input_shape):
#         self.w = self.add_weight(name="w",
#                                  shape=(self.feature_length, 1),
#                                  regularizer=l2(self.w_reg),
#                                  trainable=True)

#     def call(self, inputs, **kwargs):
#         result = tf.reduce_sum(tf.nn.embedding_lookup(self.w, inputs), axis=1)  # (batch_size, 1)
#         return result


# class DNN(Layer):
#     def __init__(self, hidden_units, activation='relu', dropout=0.):
#         """Deep Neural Network
# 		:param hidden_units: A list. Neural network hidden units.
# 		:param activation: A string. Activation function of dnn.
# 		:param dropout: A scalar. Dropout number.
# 		"""
#         super(DNN, self).__init__()
#         self.dnn_network = [Dense(units=unit, activation=activation) for unit in hidden_units]
#         self.dropout = Dropout(dropout)

#     def call(self, inputs, **kwargs):
#         x = inputs
#         for dnn in self.dnn_network:
#             x = dnn(x)
#         x = self.dropout(x)
#         return x

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Embedding, Dropout, Input
from tensorflow.keras.regularizers import l2

class WideDeep(Model):
    def __init__(self,feature_columns,hidden_units,activation='relu',
              dnn_dropout=0.,embed_reg=1e-6,w_reg=1e-6):
        """
        Wide&Deep
        :param feature_columns: A list. sparse column feature information.
        :param hidden_units: A list. Neural network hidden units.
        :param activation: A string. Activation function of dnn.
        :param dnn_dropout: A scalar. Dropout of dnn.
        :param embed_reg: A scalar. The regularizer of embedding.
        :param w_reg: A scalar. The regularizer of Linear.
        """
        super(WideDeep, self).__init__()
        self.sparse_feature_columns = feature_columns
        self.embed_layers={
            'embed_' + str(i): Embedding(input_dim=feat['feat_num'],
                                         input_length=1,
                                         output_dim=feat['embed_dim'],
                                         embeddings_initializer='random_uniform',
                                         embeddings_regularizer=l2(embed_reg))
            for i, feat in enumerate(self.sparse_feature_columns)
        }
        self.index_mapping = []
        self.feature_length = 0
        for feat in self.sparse_feature_columns:
            self.index_mapping.append(self.feature_length)
            self.feature_length += feat['feat_num']
        self.dnn_network = DNN(hidden_units,activation,dnn_dropout)
        self.linear = Linear(self.feature_length,w_reg=w_reg)
        self.final_dense = Dense(1,activation=None)
    def call(self,inputs,**kwargs):
        sparse_embed = tf.concat([self.embed_layers['embed_{}'.format(i)](inputs[:, i])
                                  for i in range(inputs.shape[1])], axis=-1)
        x = sparse_embed #(batch_size,field * embed_dim)
        #Wide
        wide_inputs = inputs + tf.convert_to_tensor(self.index_mapping)
        wide_out = self.linear(wide_inputs)
        
        #Deep
        deep_out = self.dnn_network(x)
        deep_out = self.final_dense(deep_out)
        
        #out
        outputs = tf.nn.sigmoid(0.5*wide_out+0.5*deep_out)
        return outputs
    
    def summary(self,**kwargs):
        sparse_inputs = Input(shape=(len(self.sparse_feature_columns),),dtype=tf.int32)
        Model(inputs=sparse_inputs,outputs=self.call(sparse_inputs)).summary()

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC

import sys
sys.path.append('..')
from data_process.criteo import create_criteo_dataset
import datetime
import os

# %%
if __name__ == '__main__':
    train_X, train_y = train
    test_X, test_y = test
    model = WideDeep(feature_columns, hidden_units=hidden_units, dnn_dropout=dnn_dropout)
    model.summary()
    model.compile(loss=binary_crossentropy, optimizer=Adam(learning_rate=learning_rate),
                      metrics=[AUC()])
    
    t1 = datetime.datetime.now()

    model.fit(
    train_X,
    train_y,
    epochs=epochs,
    callbacks=[EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)],  # checkpoint
    batch_size=batch_size,
    validation_split=0.1
    )
    t2 = datetime.datetime.now()
    print("时间为:%d" %(t2-t1).seconds)
    # ===========================Test==============================
    print('test AUC: %f' % model.evaluate(test_X, test_y, batch_size=batch_size)[1])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 39)]         0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_78 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_79 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_80 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_81 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_82 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_83 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_84 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_85 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_86 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_87 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_88 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_89 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_90 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_91 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_92 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_93 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_94 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_95 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_96 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_97 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_98 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_99 (T [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_100 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_101 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_102 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_103 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_104 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_105 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_106 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_107 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_108 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_109 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_110 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_111 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_112 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_113 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_114 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_115 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_116 ( [(None,)]            0           input_3[0][0]
# __________________________________________________________________________________________________
# embedding_78 (Embedding)        (None, 8)            11168       tf_op_layer_strided_slice_78[0][0
# __________________________________________________________________________________________________
# embedding_79 (Embedding)        (None, 8)            4392        tf_op_layer_strided_slice_79[0][0
# __________________________________________________________________________________________________
# embedding_80 (Embedding)        (None, 8)            10989112    tf_op_layer_strided_slice_80[0][0
# __________________________________________________________________________________________________
# embedding_81 (Embedding)        (None, 8)            3253240     tf_op_layer_strided_slice_81[0][0
# __________________________________________________________________________________________________
# embedding_82 (Embedding)        (None, 8)            2320        tf_op_layer_strided_slice_82[0][0
# __________________________________________________________________________________________________
# embedding_83 (Embedding)        (None, 8)            168         tf_op_layer_strided_slice_83[0][0
# __________________________________________________________________________________________________
# embedding_84 (Embedding)        (None, 8)            94896       tf_op_layer_strided_slice_84[0][0
# __________________________________________________________________________________________________
# embedding_85 (Embedding)        (None, 8)            4856        tf_op_layer_strided_slice_85[0][0
# __________________________________________________________________________________________________
# embedding_86 (Embedding)        (None, 8)            24          tf_op_layer_strided_slice_86[0][0
# __________________________________________________________________________________________________
# embedding_87 (Embedding)        (None, 8)            428592      tf_op_layer_strided_slice_87[0][0
# __________________________________________________________________________________________________
# embedding_88 (Embedding)        (None, 8)            41384       tf_op_layer_strided_slice_88[0][0
# __________________________________________________________________________________________________
# embedding_89 (Embedding)        (None, 8)            9250032     tf_op_layer_strided_slice_89[0][0
# __________________________________________________________________________________________________
# embedding_90 (Embedding)        (None, 8)            24952       tf_op_layer_strided_slice_90[0][0
# __________________________________________________________________________________________________
# embedding_91 (Embedding)        (None, 8)            208         tf_op_layer_strided_slice_91[0][0
# __________________________________________________________________________________________________
# embedding_92 (Embedding)        (None, 8)            93512       tf_op_layer_strided_slice_92[0][0
# __________________________________________________________________________________________________
# embedding_93 (Embedding)        (None, 8)            6671656     tf_op_layer_strided_slice_93[0][0
# __________________________________________________________________________________________________
# embedding_94 (Embedding)        (None, 8)            80          tf_op_layer_strided_slice_94[0][0
# __________________________________________________________________________________________________
# embedding_95 (Embedding)        (None, 8)            37680       tf_op_layer_strided_slice_95[0][0
# __________________________________________________________________________________________________
# embedding_96 (Embedding)        (None, 8)            16496       tf_op_layer_strided_slice_96[0][0
# __________________________________________________________________________________________________
# embedding_97 (Embedding)        (None, 8)            32          tf_op_layer_strided_slice_97[0][0
# __________________________________________________________________________________________________
# embedding_98 (Embedding)        (None, 8)            8124784     tf_op_layer_strided_slice_98[0][0
# __________________________________________________________________________________________________
# embedding_99 (Embedding)        (None, 8)            136         tf_op_layer_strided_slice_99[0][0
# __________________________________________________________________________________________________
# embedding_100 (Embedding)       (None, 8)            120         tf_op_layer_strided_slice_100[0][
# __________________________________________________________________________________________________
# embedding_101 (Embedding)       (None, 8)            766880      tf_op_layer_strided_slice_101[0][
# __________________________________________________________________________________________________
# embedding_102 (Embedding)       (None, 8)            720         tf_op_layer_strided_slice_102[0][
# __________________________________________________________________________________________________
# embedding_103 (Embedding)       (None, 8)            514072      tf_op_layer_strided_slice_103[0][
# __________________________________________________________________________________________________
# embedding_104 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_104[0][
# __________________________________________________________________________________________________
# embedding_105 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_105[0][
# __________________________________________________________________________________________________
# embedding_106 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_106[0][
# __________________________________________________________________________________________________
# embedding_107 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_107[0][
# __________________________________________________________________________________________________
# embedding_108 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_108[0][
# __________________________________________________________________________________________________
# embedding_109 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_109[0][
# __________________________________________________________________________________________________
# embedding_110 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_110[0][
# __________________________________________________________________________________________________
# embedding_111 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_111[0][
# __________________________________________________________________________________________________
# embedding_112 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_112[0][
# __________________________________________________________________________________________________
# embedding_113 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_113[0][
# __________________________________________________________________________________________________
# embedding_114 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_114[0][
# __________________________________________________________________________________________________
# embedding_115 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_115[0][
# __________________________________________________________________________________________________
# embedding_116 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_116[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 312)]        0           embedding_78[0][0]
#                                                                  embedding_79[0][0]
#                                                                  embedding_80[0][0]
#                                                                  embedding_81[0][0]
#                                                                  embedding_82[0][0]
#                                                                  embedding_83[0][0]
#                                                                  embedding_84[0][0]
#                                                                  embedding_85[0][0]
#                                                                  embedding_86[0][0]
#                                                                  embedding_87[0][0]
#                                                                  embedding_88[0][0]
#                                                                  embedding_89[0][0]
#                                                                  embedding_90[0][0]
#                                                                  embedding_91[0][0]
#                                                                  embedding_92[0][0]
#                                                                  embedding_93[0][0]
#                                                                  embedding_94[0][0]
#                                                                  embedding_95[0][0]
#                                                                  embedding_96[0][0]
#                                                                  embedding_97[0][0]
#                                                                  embedding_98[0][0]
#                                                                  embedding_99[0][0]
#                                                                  embedding_100[0][0]
#                                                                  embedding_101[0][0]
#                                                                  embedding_102[0][0]
#                                                                  embedding_103[0][0]
#                                                                  embedding_104[0][0]
#                                                                  embedding_105[0][0]
#                                                                  embedding_106[0][0]
#                                                                  embedding_107[0][0]
#                                                                  embedding_108[0][0]
#                                                                  embedding_109[0][0]
#                                                                  embedding_110[0][0]
#                                                                  embedding_111[0][0]
#                                                                  embedding_112[0][0]
#                                                                  embedding_113[0][0]
#                                                                  embedding_114[0][0]
#                                                                  embedding_115[0][0]
#                                                                  embedding_116[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_4 (TensorFlowOp [(None, 39)]         0           input_3[0][0]
# __________________________________________________________________________________________________
# dnn_2 (DNN)                     (None, 64)           121280      tf_op_layer_concat_2[0][0]
# __________________________________________________________________________________________________
# linear_2 (Linear)               (None, 1)            5042739     tf_op_layer_add_4[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            65          dnn_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_4 (TensorFlowOp [(None, 1)]          0           linear_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_5 (TensorFlowOp [(None, 1)]          0           dense_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_5 (TensorFlowOp [(None, 1)]          0           tf_op_layer_mul_4[0][0]
#                                                                  tf_op_layer_mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_2 (TensorFl [(None, 1)]          0           tf_op_layer_add_5[0][0]
# ==================================================================================================
# Total params: 45,505,996
# Trainable params: 45,505,996
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3600000 samples, validate on 400000 samples
# Epoch 1/10
# /home/xindun/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 3600000/3600000 [==============================] - 113s 31us/sample - loss: 0.4858 - auc_2: 0.7612 - val_loss: 0.4691 - val_auc_2: 0.7822
# Epoch 2/10
# 3600000/3600000 [==============================] - 104s 29us/sample - loss: 0.3883 - auc_2: 0.8620 - val_loss: 0.5078 - val_auc_2: 0.7625
# Epoch 3/10
# 3600000/3600000 [==============================] - 103s 29us/sample - loss: 0.3647 - auc_2: 0.8834 - val_loss: 0.5810 - val_auc_2: 0.7403
# 时间为:321
# 1000000/1000000 [==============================] - 14s 14us/sample - loss: 0.4671 - auc_2: 0.7823
# test AUC: 0.782312

# %%
file = '../data/Criteo/train.txt'
read_part = True
sample_num = 5000000
test_size = 0.2

embed_dim = 8
dnn_dropout = 0.5
hidden_units = [256, 128, 64]

learning_rate = 0.001
batch_size = 4096
epochs = 10 

# ========================== Create dataset =======================
feature_columns, train, test = create_criteo_dataset(file=file,
                                                     embed_dim=embed_dim,
                                                     read_part=read_part,
                                                     sample_num=sample_num,
                                                     test_size=test_size)
